# %% [markdown]
# # Simple FRED-MD + ALFRED Builder
#
# 1. Non-revised track: latest FRED-MD full history + direct tcode transforms.
# 2. Real-time track: ALFRED-based strict and balanced snapshots using 9-observation tails, with explicit source tags and availability metadata.
#
# Special rules in this notebook:
# - Global anchor-vintage backfill (all series, including ALFRED): detect the last observation month that is revised for each series, choose the first vintage at or after that month, and fill missing earlier months from that anchor to reduce leakage.
# - If anchor-vintage data is unavailable for a series, use a conservative local fallback only for the earliest missing pre-history months.
#
# Outputs:
# - CSV files in data/ALFRED/simple_outputs/
# - Final workbook data/ALFRED/fred_md_simple_balanced_dataset.xlsx

# %%
from __future__ import annotations

import importlib.util
import json
import os
import sys
from pathlib import Path

import numpy as np
import pandas as pd

ROOT = Path('/Users/OlavNikolai/TIO4900-Replication')
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))


def clean_text(value) -> str:
    if value is None:
        return ''
    if pd.isna(value):
        return ''
    return str(value).strip()


def latest_fred_md_sheet_name(xlsx_path: Path) -> str:
    xls = pd.ExcelFile(xlsx_path)
    for sheet in xls.sheet_names:
        probe = pd.read_excel(xlsx_path, sheet_name=sheet, nrows=3, header=None)
        if probe.empty:
            continue
        first = clean_text(probe.iloc[0, 0]).lower() if probe.shape[0] >= 1 and probe.shape[1] >= 1 else ''
        second = clean_text(probe.iloc[1, 0]).lower() if probe.shape[0] >= 2 and probe.shape[1] >= 1 else ''
        if first == 'sasdate' and second == 'transform:':
            return sheet
    assert False, xlsx_path


def load_latest_fred_md_matrix(source_path: Path) -> tuple[pd.DataFrame, list[str], list[int]]:
    suffix = source_path.suffix.lower()
    if suffix == '.csv':
        with source_path.open() as handle:
            header = handle.readline().strip().split(';')
            transforms = handle.readline().strip().split(';')
        assert clean_text(header[0]).lower() == 'sasdate'
        assert clean_text(transforms[0]).lower() == 'transform:'
        series_names = [clean_text(x) for x in header[1:]]
        tcodes = [int(float(x)) for x in transforms[1:]]
        panel = pd.read_csv(source_path, sep=';', decimal=',', skiprows=[1])
    elif suffix == '.xlsx':
        sheet = latest_fred_md_sheet_name(source_path)
        raw = pd.read_excel(source_path, sheet_name=sheet, header=0)
        raw = raw.rename(columns={raw.columns[0]: 'sasdate'})
        assert clean_text(raw.iloc[0, 0]).lower() == 'transform:'
        series_names = [clean_text(c) for c in raw.columns[1:]]
        tcodes = [int(float(raw.iloc[0][c])) for c in raw.columns[1:]]
        panel = raw.iloc[1:].copy()
    else:
        assert False, suffix

    panel['sasdate'] = pd.to_datetime(panel['sasdate'], errors='coerce')
    panel = panel.dropna(subset=['sasdate']).copy()
    panel['sasdate'] = (panel['sasdate'] + pd.offsets.MonthEnd(0)).dt.normalize()
    panel = panel.sort_values('sasdate').reset_index(drop=True)
    return panel, series_names, tcodes


legacy_path = ROOT / 'data/ALFRED/helpers/revised_data_pipeline.py'
spec = importlib.util.spec_from_file_location('revised_data_pipeline', legacy_path)

hs = importlib.util.module_from_spec(spec)
sys.modules['revised_data_pipeline'] = hs
spec.loader.exec_module(hs)

LATEST_MD_PATH = ROOT / 'data/ALFRED/2026-02-MD.xlsx'
OUT_DIR = ROOT / 'data/ALFRED/simple_outputs'
CACHE_PATH = ROOT / 'data/ALFRED/fred_md_simple_rt_cache.xlsx'
FINAL_XLSX = ROOT / 'data/ALFRED/fred_md_simple_balanced_dataset.xlsx'

USE_SAVED_CACHE = False
MAX_RELEASE_GAP_MONTHS = 1
API_KEY = os.getenv('FRED_API_KEY', '3c268be920acd9693b77b400b0a95cf2')

OUT_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Step 1: Load Latest FRED-MD And Build Non-Revised Baseline
#
# This cell reads the latest local FRED-MD file, extracts the series names and transformation codes, and constructs the non-revised raw and transformed panels.
#
# It also writes two baseline CSV files to `simple_outputs` for traceability: full non-revised raw history and full non-revised transformed history.

# %%
panel, series_names, tcodes = load_latest_fred_md_matrix(LATEST_MD_PATH)

nonrev_raw = panel.set_index('sasdate')[series_names].apply(pd.to_numeric, errors='coerce').sort_index()
tcode_map = dict(zip(series_names, [int(x) for x in tcodes]))

def tcode_transform(x: pd.Series, tcode: int) -> pd.Series:
    x = pd.to_numeric(x, errors='coerce')
    if tcode == 1:
        return x
    if tcode == 2:
        return x.diff(1)
    if tcode == 3:
        return x.diff(1).diff(1)
    if tcode == 4:
        return np.log(x.where(x > 0))
    if tcode == 5:
        z = x.where(x > 0)
        return np.log(z).diff(1)
    if tcode == 6:
        z = x.where(x > 0)
        return np.log(z).diff(1).diff(1)
    if tcode == 7:
        return (x / x.shift(1) - 1.0).diff(1)
    assert False, tcode

nonrev_tcode = pd.DataFrame({c: tcode_transform(nonrev_raw[c], tcode_map[c]) for c in nonrev_raw.columns}, index=nonrev_raw.index)

nonrev_raw.to_csv(OUT_DIR / 'nonrevised_raw_full_history.csv', index_label='sasdate')
nonrev_tcode.to_csv(OUT_DIR / 'nonrevised_tcode_full_history.csv', index_label='sasdate')
print({'series': len(series_names), 'rows': len(nonrev_raw), 'raw_csv': str(OUT_DIR / 'nonrevised_raw_full_history.csv')})
# Out:
# {'series': 126, 'rows': 805, 'raw_csv': '/Users/OlavNikolai/TIO4900-Replication/data/ALFRED/simple_outputs/nonrevised_raw_full_history.csv'}

# %% [markdown]
# ## Step 2: Build Mapping Registry
#
# This cell builds the series mapping registry used by the real-time pipeline stage in the helper module.
#
# The registry captures construction rules (direct, alias, formula, local-only) and is exported to CSV for auditing.

# %%
# Registry mapping is centralized in    revised_data_pipeline.py and mirrors 2026-02-series.md rules.
registry = hs.build_simple_registry(series_names=series_names, tcode_map=tcode_map)
registry.to_csv(OUT_DIR / 'mapping_registry.csv', index=False)
print({
    'registry_rows': len(registry),
    'construction_type_counts': registry['construction_type'].value_counts().to_dict(),
})
# Out:
# {'registry_rows': 126, 'construction_type_counts': {'direct_alfred': 121, 'derived_formula': 2, 'public_proxy': 2, 'direct_fred': 1}}

# %% [markdown]
# ## Step 3: Fetch Or Load Real-Time Cache And Build Final Outputs
#
# This is the main pipeline cell. It either loads an existing cache workbook or rebuilds it from ALFRED API calls, then creates balanced real-time panels.
#
# It applies anchor-vintage backfill, computes transformed real-time data, writes diagnostic CSVs, and produces the final workbook with summary sheets.

# %%
spec = importlib.util.spec_from_file_location('revised_data_pipeline', legacy_path)
hs = importlib.util.module_from_spec(spec)
sys.modules['revised_data_pipeline'] = hs
spec.loader.exec_module(hs)
print('Reloaded revised_data_pipeline helper from disk.')
# Out:
# Reloaded revised_data_pipeline helper from disk.

# %%
from time import perf_counter, sleep

start = nonrev_raw.index.min().strftime('%Y-%m-%d')
end = nonrev_raw.index.max().strftime('%Y-%m-%d')

API_LOG_EVERY_N = 1
API_MIN_INTERVAL_S = 0.55
API_COOLDOWN_ON_429_S = 12.0
API_MAX_INTERVAL_S = 1.50

api_stats = {'calls': 0, 'ok': 0, 'err': 0, 'total_s': 0.0}
endpoint_counts: dict[str, int] = {}
throttle = {'last_call_ts': 0.0, 'min_interval_s': API_MIN_INTERVAL_S}
_orig_fred_get = hs.fred_get

def _log_api(msg: str) -> None:
    ts = pd.Timestamp.now().strftime('%Y-%m-%d %H:%M:%S')
    print(f'[{ts}] {msg}')

def _paced_call() -> None:
    now = perf_counter()
    wait_needed = throttle['min_interval_s'] - (now - throttle['last_call_ts'])
    if wait_needed > 0:
        sleep(wait_needed)

def _logged_fred_get(ctx, endpoint: str, **params):
    series_id = str(params.get('series_id', ''))
    api_stats['calls'] += 1
    call_no = api_stats['calls']

    _paced_call()
    t0 = perf_counter()
    try:
        out = _orig_fred_get(ctx, endpoint, **params)
        dt = perf_counter() - t0
        throttle['last_call_ts'] = perf_counter()

        api_stats['ok'] += 1
        api_stats['total_s'] += dt
        endpoint_counts[endpoint] = endpoint_counts.get(endpoint, 0) + 1

        if call_no == 1 or call_no % API_LOG_EVERY_N == 0:
            _log_api(
                f"API OK #{call_no} endpoint={endpoint} series={series_id or '-'} "
                f"dt={dt:.2f}s ok={api_stats['ok']} err={api_stats['err']} "
                f"min_interval={throttle['min_interval_s']:.2f}s"
            )
        return out
    except Exception as exc:
        dt = perf_counter() - t0
        throttle['last_call_ts'] = perf_counter()

        api_stats['err'] += 1
        api_stats['total_s'] += dt
        endpoint_counts[endpoint] = endpoint_counts.get(endpoint, 0) + 1

        msg = str(exc)
        if '429' in msg:
            throttle['min_interval_s'] = min(throttle['min_interval_s'] + 0.10, API_MAX_INTERVAL_S)
            _log_api(
                f"RATE LIMIT HIT: raising min_interval to {throttle['min_interval_s']:.2f}s "
                f"and cooling down {API_COOLDOWN_ON_429_S:.0f}s"
            )
            sleep(API_COOLDOWN_ON_429_S)

        _log_api(
            f"API ERROR #{call_no} endpoint={endpoint} series={series_id or '-'} "
            f"dt={dt:.2f}s error={type(exc).__name__}: {exc}"
        )
        raise

if USE_SAVED_CACHE and CACHE_PATH.exists():
    _log_api(f'Using saved cache at {CACHE_PATH}; no ALFRED API calls will be made.')
    cache_payload = hs.load_cache(CACHE_PATH)
    cache_mode = 'loaded'
else:
    if not API_KEY:
        raise RuntimeError('FRED_API_KEY is required when rebuilding cache.')
    hs.fred_get = _logged_fred_get
    stage0 = perf_counter()
    _log_api(
        f"Starting ALFRED API fetch stage (run_cache_stage). "
        f"base_min_interval={API_MIN_INTERVAL_S:.2f}s cooldown_on_429={API_COOLDOWN_ON_429_S:.0f}s"
    )
    try:
        cache_payload = hs.run_cache_stage(
            registry=registry,
            cache_path=CACHE_PATH,
            start=start,
            end=end,
            api_key=API_KEY,
            pause_sec=0.20,
        )
        cache_mode = 'rebuilt'
    except Exception:
        elapsed = perf_counter() - stage0
        avg = (api_stats['total_s'] / api_stats['calls']) if api_stats['calls'] else 0.0
        _log_api(
            f"ALFRED API fetch FAILED after {elapsed:.1f}s "
            f"calls={api_stats['calls']} ok={api_stats['ok']} err={api_stats['err']} avg_api={avg:.2f}s"
        )
        if endpoint_counts:
            _log_api(f'Endpoint counts so far: {endpoint_counts}')
        raise
    finally:
        hs.fred_get = _orig_fred_get

    elapsed = perf_counter() - stage0
    avg = (api_stats['total_s'] / api_stats['calls']) if api_stats['calls'] else 0.0
    _log_api(
        f"ALFRED API fetch DONE in {elapsed:.1f}s "
        f"calls={api_stats['calls']} ok={api_stats['ok']} err={api_stats['err']} avg_api={avg:.2f}s "
        f"final_min_interval={throttle['min_interval_s']:.2f}s"
    )
    if endpoint_counts:
        _log_api(f'Endpoint counts: {endpoint_counts}')
    if api_stats['err'] > 0:
        _log_api("API errors occurred. Inspect cache_payload.get('error_log', pd.DataFrame()).")

final_payload = hs.run_final_stage(
    registry=registry,
    cache_payload=cache_payload,
    final_path=FINAL_XLSX,
    start=start,
    end=end,
    max_release_gap_months=MAX_RELEASE_GAP_MONTHS,
 )

raw_bal = final_payload['snapshot_raw_balanced'].copy()
src_bal = final_payload['snapshot_source_balanced'].copy()
raw_bal['decision_date'] = pd.to_datetime(raw_bal['decision_date'])
src_bal['decision_date'] = pd.to_datetime(src_bal['decision_date'])
raw_bal = raw_bal.set_index('decision_date').sort_index()
src_bal = src_bal.set_index('decision_date').sort_index()

HIST_VINTAGE_DIRS = [
    ROOT / 'data/ALFRED/Historical-vintages-of-FRED-MD-1999-08-to-2024-12',
]
raw_bal, src_bal, filled_counts = hs.apply_anchor_backfill_to_balanced(
    raw_bal=raw_bal,
    src_bal=src_bal,
    registry=registry,
    nonrev_raw=nonrev_raw,
    vintage_dirs=HIST_VINTAGE_DIRS,
    tag='FILL_ANCHOR_VINTAGE_PRE_TSTOP',
)

rt_tcode = hs.apply_tcodes_panel(raw_bal, tcode_map, series_names)

raw_bal.to_csv(OUT_DIR / 'realtime_raw_balanced.csv', index_label='decision_date')
rt_tcode.to_csv(OUT_DIR / 'realtime_tcode_balanced.csv', index_label='decision_date')
src_bal.to_csv(OUT_DIR / 'realtime_source_tags.csv', index_label='decision_date')
cache_payload.get('availability_audit', pd.DataFrame()).to_csv(OUT_DIR / 'availability_audit.csv', index=False)
cache_payload.get('revision_audit', pd.DataFrame()).to_csv(OUT_DIR / 'revision_audit.csv', index=False)

source_counts = src_bal[series_names].stack().astype(str).value_counts()
source_tag_summary = pd.DataFrame({
    'source_tag': source_counts.index,
    'count': source_counts.values,
})
source_tag_summary['share_pct'] = (
    100.0 * source_tag_summary['count'] / source_tag_summary['count'].sum()
).round(2)

missing_by_series = raw_bal[series_names].isna().sum().astype(int)
dominant_source = {}
for s in series_names:
    vc = src_bal[s].astype(str).value_counts(dropna=False)
    dominant_source[s] = vc.index[0] if len(vc) else ''

series_quality = pd.DataFrame({
    'series': series_names,
    'missing_count': [int(missing_by_series[s]) for s in series_names],
    'missing_share_pct': [round(100.0 * missing_by_series[s] / len(raw_bal), 2) for s in series_names],
    'dominant_source_tag': [dominant_source[s] for s in series_names],
    'anchor_backfill_cells': [int(filled_counts.get(s, 0)) for s in series_names],
})

series_map = registry[[
    'mnemonic_hs',
    'tcode_hs',
    'construction_type',
    'target_series_id',
    'raw_formula',
    'pub_lag_mode',
    'pub_lag_months',
    'pub_lag_schedule_json',
    'revision_class',
]].rename(columns={
    'mnemonic_hs': 'series',
    'tcode_hs': 'tcode',
    'target_series_id': 'target_series',
})

overview = pd.DataFrame([
    {'metric': 'build_timestamp_utc', 'value': pd.Timestamp.now('UTC').isoformat()},
    {'metric': 'cache_mode', 'value': cache_mode},
    {'metric': 'decision_start', 'value': start},
    {'metric': 'decision_end', 'value': end},
    {'metric': 'series_count', 'value': int(len(series_names))},
    {'metric': 'decision_months', 'value': int(len(raw_bal))},
    {'metric': 'remaining_missing_cells', 'value': int(raw_bal[series_names].isna().sum().sum())},
    {'metric': 'anchor_backfill_series_count', 'value': int(len(filled_counts))},
    {'metric': 'anchor_backfill_cell_count', 'value': int(sum(filled_counts.values()))},
    {'metric': 'api_calls', 'value': int(api_stats['calls'])},
    {'metric': 'api_errors', 'value': int(api_stats['err'])},
])

readme = pd.DataFrame([
    {'section': 'Use this workbook for', 'detail': 'Quick understanding of data quality and final transformed panel.'},
    {'section': 'Main data sheet', 'detail': 'rt_tcode_balanced (final transformed monthly panel used for modeling).'},
    {'section': 'Data source mix', 'detail': 'source_tag_summary shows which fill/source tags dominate the panel.'},
    {'section': 'Series-level health', 'detail': 'series_quality highlights missingness and dominant source per series.'},
    {'section': 'Raw/source full matrices', 'detail': 'See CSV outputs in data/ALFRED/simple_outputs for full raw and source-tag matrices.'},
])

diag_checks = final_payload.get('diag_checks', pd.DataFrame()).copy()
error_log = cache_payload.get('error_log', pd.DataFrame()).copy()
if error_log.empty:
    error_log_summary = pd.DataFrame([{'status': 'no_errors_logged'}])
else:
    keep_cols = [c for c in ['stage', 'series_id', 'error'] if c in error_log.columns]
    error_log_summary = error_log[keep_cols].copy()
    if 'error' in error_log_summary.columns:
        error_log_summary['error'] = error_log_summary['error'].astype(str).str.slice(0, 200)

raw_last24 = raw_bal.tail(24).reset_index()
source_last24 = src_bal.tail(24).reset_index()

sheet_plan = [
    'readme',
    'overview',
    'series_map',
    'series_quality',
    'source_tag_summary',
    'rt_tcode_balanced',
    'rt_raw_last24m',
    'rt_source_last24m',
    'diag_checks',
    'error_log',
]

with pd.ExcelWriter(FINAL_XLSX, engine='openpyxl') as w:
    readme.to_excel(w, sheet_name='readme', index=False)
    overview.to_excel(w, sheet_name='overview', index=False)
    series_map.to_excel(w, sheet_name='series_map', index=False)
    series_quality.to_excel(w, sheet_name='series_quality', index=False)
    source_tag_summary.to_excel(w, sheet_name='source_tag_summary', index=False)
    rt_tcode.reset_index().to_excel(w, sheet_name='rt_tcode_balanced', index=False)
    raw_last24.to_excel(w, sheet_name='rt_raw_last24m', index=False)
    source_last24.to_excel(w, sheet_name='rt_source_last24m', index=False)
    diag_checks.to_excel(w, sheet_name='diag_checks', index=False)
    error_log_summary.to_excel(w, sheet_name='error_log', index=False)

print({
    'cache_mode': cache_mode,
    'final_xlsx': str(FINAL_XLSX),
    'csv_dir': str(OUT_DIR),
    'xlsx_sheets': sheet_plan,
    'remaining_missing_cells': int(raw_bal[series_names].isna().sum().sum()),
})
# Out:
# [2026-03-20 10:29:06] Starting ALFRED API fetch stage (run_cache_stage). base_min_interval=0.55s cooldown_on_429=12s
# [2026-03-20 10:29:07] API OK #1 endpoint=series/observations series=AAA dt=1.18s ok=1 err=0 min_interval=0.55s
# [2026-03-20 10:29:08] API OK #2 endpoint=series/observations series=AAAFFM dt=0.36s ok=2 err=0 min_interval=0.55s
# [2026-03-20 10:29:10] API OK #3 endpoint=series/observations series=ACOGNO dt=1.57s ok=3 err=0 min_interval=0.55s
# [2026-03-20 10:29:11] API OK #4 endpoint=series/observations series=AMDMUO dt=0.43s ok=4 err=0 min_interval=0.55s
# [2026-03-20 10:29:12] API OK #5 endpoint=series/observations series=ANDENO dt=0.46s ok=5 err=0 min_interval=0.55s
# [2026-03-20 10:29:13] API OK #6 endpoint=series/observations series=AWHMAN dt=0.37s ok=6 err=0 min_interval=0.55s
# [2026-03-20 10:29:14] API OK #7 endpoint=series/observations series=AWOTMAN dt=0.44s ok=7 err=0 min_interval=0.55s
# [2026-03-20 10:29:15] API OK #8 endpoint=series/observations series=BAA dt=0.54s ok=8 err=0 min_interval=0.55s
# [2026-03-20 10:29:16] API OK #9 endpoint=series/observations series=BAAFFM dt=0.72s ok=9 err=0 min_interval=0.55s
# [2026-03-20 10:29:17] API OK #10 endpoint=series/observations series=BOGMBASE dt=0.36s ok=10 err=0 min_interval=0.55s
# [2026-03-20 10:29:18] API OK #11 endpoint=series/observations series=BUSINV dt=0.38s ok=11 err=0 min_interval=0.55s
# [2026-03-20 10:29:19] API OK #12 endpoint=series/observations series=BUSLOANS dt=0.47s ok=12 err=0 min_interval=0.55s
# [2026-03-20 10:29:20] API OK #13 endpoint=series/observations series=CE16OV dt=0.57s ok=13 err=0 min_interval=0.55s
# [2026-03-20 10:29:21] API OK #14 endpoint=series/observations series=CES0600000007 dt=0.38s ok=14 err=0 min_interval=0.55s
# [2026-03-20 10:29:22] API OK #15 endpoint=series/observations series=CES0600000008 dt=0.36s ok=15 err=0 min_interval=0.55s
# [2026-03-20 10:29:23] API OK #16 endpoint=series/observations series=CES1021000001 dt=0.39s ok=16 err=0 min_interval=0.55s
# [2026-03-20 10:29:24] API OK #17 endpoint=series/observations series=CES2000000008 dt=0.45s ok=17 err=0 min_interval=0.55s
# [2026-03-20 10:29:26] API OK #18 endpoint=series/observations series=CES3000000008 dt=0.87s ok=18 err=0 min_interval=0.55s
# [2026-03-20 10:29:27] API OK #19 endpoint=series/observations series=CLF16OV dt=0.82s ok=19 err=0 min_interval=0.55s
# [2026-03-20 10:29:28] API OK #20 endpoint=series/observations series=CMRMTSPL dt=0.37s ok=20 err=0 min_interval=0.55s
# [2026-03-20 10:29:29] API OK #21 endpoint=series/observations series=CP3M dt=0.40s ok=21 err=0 min_interval=0.55s
# [2026-03-20 10:29:30] API OK #22 endpoint=series/observations series=CPFFM dt=0.49s ok=22 err=0 min_interval=0.55s
# [2026-03-20 10:29:31] API OK #23 endpoint=series/observations series=CPIAPPSL dt=0.37s ok=23 err=0 min_interval=0.55s
# [2026-03-20 10:29:33] API OK #24 endpoint=series/observations series=CPIAUCSL dt=1.84s ok=24 err=0 min_interval=0.55s
# [2026-03-20 10:29:35] API OK #25 endpoint=series/observations series=CPIMEDSL dt=1.08s ok=25 err=0 min_interval=0.55s
# [2026-03-20 10:29:36] API OK #26 endpoint=series/observations series=CPITRNSL dt=0.47s ok=26 err=0 min_interval=0.55s
# [2026-03-20 10:29:37] API OK #27 endpoint=series/observations series=CPIULFSL dt=0.47s ok=27 err=0 min_interval=0.55s
# [2026-03-20 10:29:38] API OK #28 endpoint=series/observations series=CUMFNS dt=0.59s ok=28 err=0 min_interval=0.55s
# [2026-03-20 10:29:39] API OK #29 endpoint=series/observations series=CUSR0000SA0L2 dt=0.38s ok=29 err=0 min_interval=0.55s
# [2026-03-20 10:29:40] API OK #30 endpoint=series/observations series=CUSR0000SA0L5 dt=0.37s ok=30 err=0 min_interval=0.55s
# [2026-03-20 10:29:41] API OK #31 endpoint=series/observations series=CUSR0000SAC dt=0.37s ok=31 err=0 min_interval=0.55s
# [2026-03-20 10:29:42] API OK #32 endpoint=series/observations series=CUSR0000SAD dt=0.38s ok=32 err=0 min_interval=0.55s
# [2026-03-20 10:29:43] API OK #33 endpoint=series/observations series=CUSR0000SAS dt=0.43s ok=33 err=0 min_interval=0.55s
# [2026-03-20 10:29:44] API OK #34 endpoint=series/observations series=DDURRG3M086SBEA dt=0.40s ok=34 err=0 min_interval=0.55s
# [2026-03-20 10:29:45] API OK #35 endpoint=series/observations series=DGORDER dt=0.39s ok=35 err=0 min_interval=0.55s
# [2026-03-20 10:29:46] API OK #36 endpoint=series/observations series=DMANEMP dt=0.41s ok=36 err=0 min_interval=0.55s
# [2026-03-20 10:29:46] API OK #37 endpoint=series/observations series=DNDGRG3M086SBEA dt=0.37s ok=37 err=0 min_interval=0.55s
# [2026-03-20 10:29:47] API OK #38 endpoint=series/observations series=DPCERA3M086SBEA dt=0.39s ok=38 err=0 min_interval=0.55s
# [2026-03-20 10:29:48] API OK #39 endpoint=series/observations series=DSERRG3M086SBEA dt=0.38s ok=39 err=0 min_interval=0.55s
# [2026-03-20 10:29:49] API OK #40 endpoint=series/observations series=DTCOLNVHFNM dt=0.54s ok=40 err=0 min_interval=0.55s
# [2026-03-20 10:29:50] API OK #41 endpoint=series/observations series=DTCTHFNM dt=0.37s ok=41 err=0 min_interval=0.55s
# [2026-03-20 10:29:51] API OK #42 endpoint=series/observations series=EXCAUS dt=0.37s ok=42 err=0 min_interval=0.55s
# [2026-03-20 10:29:52] API OK #43 endpoint=series/observations series=EXJPUS dt=0.38s ok=43 err=0 min_interval=0.55s
# [2026-03-20 10:29:53] API OK #44 endpoint=series/observations series=EXSZUS dt=0.38s ok=44 err=0 min_interval=0.55s
# [2026-03-20 10:29:54] API OK #45 endpoint=series/observations series=EXUSUK dt=0.41s ok=45 err=0 min_interval=0.55s
# [2026-03-20 10:29:55] API OK #46 endpoint=series/observations series=FEDFUNDS dt=0.39s ok=46 err=0 min_interval=0.55s
# [2026-03-20 10:29:56] API OK #47 endpoint=series/observations series=GS1 dt=0.36s ok=47 err=0 min_interval=0.55s
# [2026-03-20 10:29:57] API OK #48 endpoint=series/observations series=GS10 dt=0.36s ok=48 err=0 min_interval=0.55s
# [2026-03-20 10:29:58] API OK #49 endpoint=series/observations series=GS5 dt=0.47s ok=49 err=0 min_interval=0.55s
# [2026-03-20 10:29:59] API OK #50 endpoint=series/observations series=HOUST dt=0.36s ok=50 err=0 min_interval=0.55s
# [2026-03-20 10:30:00] API OK #51 endpoint=series/observations series=HOUSTMW dt=0.42s ok=51 err=0 min_interval=0.55s
# [2026-03-20 10:30:01] API OK #52 endpoint=series/observations series=HOUSTNE dt=0.40s ok=52 err=0 min_interval=0.55s
# [2026-03-20 10:30:02] API OK #53 endpoint=series/observations series=HOUSTS dt=0.45s ok=53 err=0 min_interval=0.55s
# [2026-03-20 10:30:03] API OK #54 endpoint=series/observations series=HOUSTW dt=0.59s ok=54 err=0 min_interval=0.55s
# [2026-03-20 10:30:05] API OK #55 endpoint=series/observations series=ICSA dt=1.72s ok=55 err=0 min_interval=0.55s
# [2026-03-20 10:30:07] API OK #56 endpoint=series/observations series=INDPRO dt=1.55s ok=56 err=0 min_interval=0.55s
# [2026-03-20 10:30:08] API OK #57 endpoint=series/observations series=INVEST dt=0.47s ok=57 err=0 min_interval=0.55s
# [2026-03-20 10:30:09] API OK #58 endpoint=series/observations series=IPB51222S dt=0.43s ok=58 err=0 min_interval=0.55s
# [2026-03-20 10:30:10] API OK #59 endpoint=series/observations series=IPBUSEQ dt=0.39s ok=59 err=0 min_interval=0.55s
# [2026-03-20 10:30:11] API OK #60 endpoint=series/observations series=IPCONGD dt=0.40s ok=60 err=0 min_interval=0.55s
# [2026-03-20 10:30:12] API OK #61 endpoint=series/observations series=IPDCONGD dt=0.43s ok=61 err=0 min_interval=0.55s
# [2026-03-20 10:30:13] API OK #62 endpoint=series/observations series=IPDMAT dt=0.40s ok=62 err=0 min_interval=0.55s
# [2026-03-20 10:30:14] API OK #63 endpoint=series/observations series=IPFINAL dt=0.39s ok=63 err=0 min_interval=0.55s
# [2026-03-20 10:30:15] API OK #64 endpoint=series/observations series=IPFPNSS dt=0.37s ok=64 err=0 min_interval=0.55s
# [2026-03-20 10:30:16] API OK #65 endpoint=series/observations series=IPFUELS dt=0.55s ok=65 err=0 min_interval=0.55s
# [2026-03-20 10:30:17] API OK #66 endpoint=series/observations series=IPMANSICS dt=0.56s ok=66 err=0 min_interval=0.55s
# [2026-03-20 10:30:18] API OK #67 endpoint=series/observations series=IPMAT dt=0.40s ok=67 err=0 min_interval=0.55s
# [2026-03-20 10:30:21] API OK #68 endpoint=series/observations series=IPNCONGD dt=2.51s ok=68 err=0 min_interval=0.55s
# [2026-03-20 10:30:22] API OK #69 endpoint=series/observations series=IPNMAT dt=0.39s ok=69 err=0 min_interval=0.55s
# [2026-03-20 10:30:25] API OK #70 endpoint=series/observations series=ISRATIO dt=2.18s ok=70 err=0 min_interval=0.55s
# [2026-03-20 10:30:26] API OK #71 endpoint=series/observations series=JTSJOL dt=0.38s ok=71 err=0 min_interval=0.55s
# [2026-03-20 10:30:27] API OK #72 endpoint=series/observations series=M1SL dt=0.40s ok=72 err=0 min_interval=0.55s
# [2026-03-20 10:30:28] API OK #73 endpoint=series/observations series=M2REAL dt=0.43s ok=73 err=0 min_interval=0.55s
# [2026-03-20 10:30:29] API OK #74 endpoint=series/observations series=M2SL dt=0.42s ok=74 err=0 min_interval=0.55s
# [2026-03-20 10:30:30] API OK #75 endpoint=series/observations series=MANEMP dt=0.38s ok=75 err=0 min_interval=0.55s
# [2026-03-20 10:30:31] API OK #76 endpoint=series/observations series=NDMANEMP dt=0.51s ok=76 err=0 min_interval=0.55s
# [2026-03-20 10:30:32] API OK #77 endpoint=series/observations series=NONBORRES dt=0.87s ok=77 err=0 min_interval=0.55s
# [2026-03-20 10:30:33] API OK #78 endpoint=series/observations series=NONREVSL dt=0.39s ok=78 err=0 min_interval=0.55s
# [2026-03-20 10:30:34] API OK #79 endpoint=series/observations series=OILPRICE dt=0.41s ok=79 err=0 min_interval=0.55s
# [2026-03-20 10:30:35] API OK #80 endpoint=series/observations series=PAYEMS dt=0.66s ok=80 err=0 min_interval=0.55s
# [2026-03-20 10:30:36] API OK #81 endpoint=series/observations series=PCEPI dt=0.38s ok=81 err=0 min_interval=0.55s
# [2026-03-20 10:30:37] API OK #82 endpoint=series/observations series=PERMIT dt=0.39s ok=82 err=0 min_interval=0.55s
# [2026-03-20 10:30:38] API OK #83 endpoint=series/observations series=PERMITMW dt=0.40s ok=83 err=0 min_interval=0.55s
# [2026-03-20 10:30:39] API OK #84 endpoint=series/observations series=PERMITNE dt=0.39s ok=84 err=0 min_interval=0.55s
# [2026-03-20 10:30:40] API OK #85 endpoint=series/observations series=PERMITS dt=0.39s ok=85 err=0 min_interval=0.55s
# [2026-03-20 10:30:41] API OK #86 endpoint=series/observations series=PERMITW dt=0.38s ok=86 err=0 min_interval=0.55s
# [2026-03-20 10:30:42] API OK #87 endpoint=series/observations series=PI dt=0.38s ok=87 err=0 min_interval=0.55s
# [2026-03-20 10:30:43] API OK #88 endpoint=series/observations series=PPICMM dt=0.41s ok=88 err=0 min_interval=0.55s
# [2026-03-20 10:30:44] API OK #89 endpoint=series/observations series=REALLN dt=0.50s ok=89 err=0 min_interval=0.55s
# [2026-03-20 10:30:45] API OK #90 endpoint=series/observations series=RETAIL dt=0.48s ok=90 err=0 min_interval=0.55s
# [2026-03-20 10:30:46] API OK #91 endpoint=series/observations series=RPI dt=0.62s ok=91 err=0 min_interval=0.55s
# [2026-03-20 10:31:04] API ERROR #92 endpoint=series/observations series=SP500 dt=17.46s error=FredApiError: Request failed after 6 attempts: series/observations
# [2026-03-20 10:31:05] API OK #93 endpoint=series/observations series=SP500 dt=0.40s ok=92 err=1 min_interval=0.55s
# [2026-03-20 10:31:06] API OK #94 endpoint=series/observations series=SRVPRD dt=0.39s ok=93 err=1 min_interval=0.55s
# [2026-03-20 10:31:07] API OK #95 endpoint=series/observations series=T10YFFM dt=0.39s ok=94 err=1 min_interval=0.55s
# [2026-03-20 10:31:08] API OK #96 endpoint=series/observations series=T1YFFM dt=0.50s ok=95 err=1 min_interval=0.55s
# [2026-03-20 10:31:09] API OK #97 endpoint=series/observations series=T5YFFM dt=0.36s ok=96 err=1 min_interval=0.55s
# [2026-03-20 10:31:10] API OK #98 endpoint=series/observations series=TB3MS dt=0.41s ok=97 err=1 min_interval=0.55s
# [2026-03-20 10:31:11] API OK #99 endpoint=series/observations series=TB3SMFFM dt=0.38s ok=98 err=1 min_interval=0.55s
# [2026-03-20 10:31:12] API OK #100 endpoint=series/observations series=TB6MS dt=0.35s ok=99 err=1 min_interval=0.55s
# [2026-03-20 10:31:14] API OK #101 endpoint=series/observations series=TB6SMFFM dt=1.46s ok=100 err=1 min_interval=0.55s
# [2026-03-20 10:31:15] API OK #102 endpoint=series/observations series=TOTRESNS dt=0.48s ok=101 err=1 min_interval=0.55s
# [2026-03-20 10:31:16] API OK #103 endpoint=series/observations series=TWEXAFEGSMTH dt=0.42s ok=102 err=1 min_interval=0.55s
# [2026-03-20 10:31:17] API OK #104 endpoint=series/observations series=UEMP15OV dt=0.40s ok=103 err=1 min_interval=0.55s
# [2026-03-20 10:31:18] API OK #105 endpoint=series/observations series=UEMP15T26 dt=0.38s ok=104 err=1 min_interval=0.55s
# [2026-03-20 10:31:19] API OK #106 endpoint=series/observations series=UEMP27OV dt=0.48s ok=105 err=1 min_interval=0.55s
# [2026-03-20 10:31:20] API OK #107 endpoint=series/observations series=UEMP5TO14 dt=0.40s ok=106 err=1 min_interval=0.55s
# [2026-03-20 10:31:21] API OK #108 endpoint=series/observations series=UEMPLT5 dt=0.58s ok=107 err=1 min_interval=0.55s
# [2026-03-20 10:31:22] API OK #109 endpoint=series/observations series=UEMPMEAN dt=0.38s ok=108 err=1 min_interval=0.55s
# [2026-03-20 10:31:23] API OK #110 endpoint=series/observations series=UMCSENT dt=0.37s ok=109 err=1 min_interval=0.55s
# [2026-03-20 10:31:23] API OK #111 endpoint=series/observations series=UNEMPLOY dt=0.37s ok=110 err=1 min_interval=0.55s
# [2026-03-20 10:31:25] API OK #112 endpoint=series/observations series=UNRATE dt=0.60s ok=111 err=1 min_interval=0.55s
# [2026-03-20 10:31:26] API OK #113 endpoint=series/observations series=USCONS dt=0.60s ok=112 err=1 min_interval=0.55s
# [2026-03-20 10:31:27] API OK #114 endpoint=series/observations series=USFIRE dt=0.37s ok=113 err=1 min_interval=0.55s
# [2026-03-20 10:31:28] API OK #115 endpoint=series/observations series=USGOOD dt=0.36s ok=114 err=1 min_interval=0.55s
# [2026-03-20 10:31:29] API OK #116 endpoint=series/observations series=USGOVT dt=0.40s ok=115 err=1 min_interval=0.55s
# [2026-03-20 10:31:30] API OK #117 endpoint=series/observations series=USTPU dt=0.38s ok=116 err=1 min_interval=0.55s
# [2026-03-20 10:31:31] API OK #118 endpoint=series/observations series=USTRADE dt=0.46s ok=117 err=1 min_interval=0.55s
# [2026-03-20 10:31:32] API OK #119 endpoint=series/observations series=USWTRADE dt=0.54s ok=118 err=1 min_interval=0.55s
# [2026-03-20 10:31:49] API ERROR #120 endpoint=series/observations series=VIXCLS dt=16.61s error=FredApiError: Request failed after 6 attempts: series/observations
# [2026-03-20 10:31:50] API OK #121 endpoint=series/observations series=VIXCLS dt=1.03s ok=119 err=2 min_interval=0.55s
# [2026-03-20 10:31:51] API OK #122 endpoint=series/observations series=W875RX1 dt=0.39s ok=120 err=2 min_interval=0.55s
# [2026-03-20 10:31:52] API OK #123 endpoint=series/observations series=WPSFD49207 dt=0.54s ok=121 err=2 min_interval=0.55s
# [2026-03-20 10:31:53] API OK #124 endpoint=series/observations series=WPSFD49502 dt=0.37s ok=122 err=2 min_interval=0.55s
# [2026-03-20 10:31:54] API OK #125 endpoint=series/observations series=WPSID61 dt=0.36s ok=123 err=2 min_interval=0.55s
# [2026-03-20 10:31:55] API OK #126 endpoint=series/observations series=WPSID62 dt=0.38s ok=124 err=2 min_interval=0.55s
# [2026-03-20 10:32:40] ALFRED API fetch DONE in 214.4s calls=126 ok=124 err=2 avg_api=0.80s final_min_interval=0.55s
# [2026-03-20 10:32:40] Endpoint counts: {'series/observations': 126}
# [2026-03-20 10:32:40] API errors occurred. Inspect cache_payload.get('error_log', pd.DataFrame()).
# {'cache_mode': 'rebuilt', 'final_xlsx': '/Users/OlavNikolai/TIO4900-Replication/data/ALFRED/fred_md_simple_balanced_dataset.xlsx', 'csv_dir': '/Users/OlavNikolai/TIO4900-Replication/data/ALFRED/simple_outputs', 'xlsx_sheets': ['readme', 'overview', 'series_map', 'series_quality', 'source_tag_summary', 'rt_tcode_balanced', 'rt_raw_last24m', 'rt_source_last24m', 'diag_checks', 'error_log'], 'remaining_missing_cells': 780}

# %% [markdown]
# ## Step 4: Quick Sanity Summary
#
# This cell prints a compact quality summary: number of series, row counts, remaining missing values, and the top source tags in the balanced real-time panel.
#
# Use it as a lightweight check before consuming the final workbook in downstream modeling.

# %%
summary = pd.DataFrame([
    {'metric': 'series_total', 'value': len(series_names)},
    {'metric': 'nonrevised_rows', 'value': int(len(nonrev_raw))},
    {'metric': 'realtime_rows', 'value': int(len(raw_bal))},
    {'metric': 'realtime_missing_after_balance', 'value': int(raw_bal[series_names].isna().sum().sum())},
])
print(summary.to_string(index=False))
print('Top source tags:')
print(src_bal[series_names].stack().astype(str).value_counts().head(12).to_string())
# Out:
#                         metric  value
#                   series_total    126
#                nonrevised_rows    805
#                  realtime_rows    805
# realtime_missing_after_balance    780
# Top source tags:
# FILL_RELEASE_GAP             48211
# STRICT                       44958
# FILL_NONREVISED_FRED          6143
# FILL_PRE_VINTAGE_EARLIEST     1338
#                                780
